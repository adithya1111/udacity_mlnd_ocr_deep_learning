# %%
from collections import OrderedDict
from data_generator import *
from model import OCR_Model
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import json
from data_generator import *
slice_height = 40
slice_width = 20
max_slice_num = 24
y_max_len = 40
max_img_height = 40
batch_size = 5
input_folder = "/home/CONCURASP/kumara/udacity_ocr/data/ramdisk/max/90kDICT32px/"
vocab_file = "/home/CONCURASP/kumara/udacity_ocr_refactor/src/rcptAlphabet.json"
with open(vocab_file) as fp:
    rcpt_vocabulary = ['UNK', 'STOP','PAD'] + json.load(fp)
    rcpt_map = {}
    for i in range(len(rcpt_vocabulary)):
        rcpt_map[rcpt_vocabulary[i]] = i
    char_num = len(rcpt_map)
# from model import OCR_Model
# model = OCR_Model(char_num).model
# print(model.summary())
# model.fit_generator(gen_data(input_folder,input_folder+"adi_train.txt",rcpt_map,batch_size),
#                         samples_per_epoch=2000, nb_epoch=20,   
#                         validation_data=gen_data(input_folder,input_folder+"adi_train.txt",rcpt_map,batch_size),
#                         nb_val_samples=15000,
#                         verbose=1)
# model.save('/home/CONCURASP/kumara/udacity_ocr_refactor/model/ocr_extraction_model.h5', overwrite=True)

# %%
from collections import OrderedDict
from data_generator import *
from model import OCR_Model
gen = gen_data('/home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/','/home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/adi_train.txt',rcpt_map,32)
for i,j in gen:
    print(i.shape,j.shape)
# Out:
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/4/296_TRIMARAN_80684.jpg TRIMARAN
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/2/213_ability_276.jpg ability
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/2/146_withdrew_86917.jpg withdrew
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/5/241_impressionable_38473.jpg impressionable
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/6/90_LLOYD_44919.jpg LLOYD
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2425/1/9_RAIDER_62210.jpg RAIDER
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/6/206_blavatsky_7942.jpg blavatsky
# /home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/2424/2/331_Beforehand_6678.jpg Beforehand
# ...

# %%
# # Define the rnn ouput vocab

# vocab_file = '/home/CONCURASP/kumara/udacity_ocr_refactor/src/rcptAlphabet.json'
# with open(vocab_file) as fp:
#     rcpt_vocabulary = ['UNK', 'STOP','PAD'] + json.load(fp)
#     rcpt_map = {}
#     for i in range(len(rcpt_vocabulary)):
#         rcpt_map[rcpt_vocabulary[i]] = i
# char_num = len(rcpt_map)
# obj = OCR_Model(char_num,"/home/CONCURASP/kumara/udacity_ocr_refactor/model/ocr_extraction_model.h5")              
# def convert_img_boxes(image_path):
#     max_slice_num = 24
#     slice_width = 20
#     slice_height = 40
#     #show_image(img)
#     img = pre_process_image(image_path)
#     output = np.zeros((max_slice_num, slice_height, slice_width, 1))
#     X_train = np.zeros((1, max_slice_num, slice_height, slice_width, 1))
#     if img is not None:                        
#         num_slices_img = int(img.shape[1]/slice_width)
#         num_slices = min(num_slices_img,max_slice_num)
#         #print('number of slices',num_slices)
#         for k in range(1, num_slices+1):
#             output[k-1, :, :,0] = img[:,(k-1)*slice_width:k*slice_width]
#     X_train[0, :, :, :, :] = output    
#     pred = obj.model.predict(X_train)

#     print(pred)
#     return pred
# #     return_dict = OrderedDict()
# #     proba_list = []
# #     for i in range(0, len(pred)):
# #         a = "".join([char_map_rever.get(x) for x in np.argmax(pred[i], axis=1)])
# #         pred_string = a[:a.find("|")]
#     #print(pred_string)
#     #return pred_string
#     #show_image(img_processed)
# # def show_image(img):        
# #     imgplot = plt.imshow(img)
# #     plt.show()

# base_path='/home/CONCURASP/kumara/udacity_ocr_refactor/data/'
# path = '2697/6/459_Silliest_70946.jpg' 

# final_path = base_path+path
# #pred = convert_img_boxes(final_path)

# %%
get_text('/home/CONCURASP/kumara/udacity_ocr_refactor/src/rcptAlphabet.json',pred)

# %%
gen = gen_data('/home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/','/home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/adi_train.txt',rcpt_map,32)
for i,j in gen:
    print(i.shape,j.shape)
# Out:
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (157, 24, 40, 20, 1) (157, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# (156, 24, 40, 20, 1) (156, 40, 97)
# ...

# %%
base_path='/home/CONCURASP/kumara/udacity_ocr/data/ramdisk/max/90kDICT32px/'
path = '2697/6/425_Sullied_76002.jpg' 
final_path = base_path+path

# %%
import pandas as pd
df = pd.read_csv('/home/CONCURASP/kumara/udacity_ocr_refactor/data/ramdisk/max/90kDICT32px/adi_train.txt',sep=' ')
df.shape
# Out:
# (9999, 2)
